# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Домашнее задание 5
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_pds_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате `ipynb`.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков можно использовать без ограничений.**
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $\LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 20 баллов
# * Задача 2 &mdash; 15 баллов
# * Задача 3 &mdash;  20 баллов
# * Задача 4 &mdash;  30 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 5 &mdash; 25 баллов
# * Задача 6 &mdash;  40 баллов
#
# -----

# %%
# Bot check

# HW_ID: phds_hw5
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: not final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %%
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
import typing as tp

sns.set_style("whitegrid")

# %% [markdown]
# ### <b><i><font color="blue">Легкая часть</font></i></b>
#
# ### Задача 1.
#
# **1.** Найдите оценку параметра $\theta$ методом максимального правдоподобия по выборке размера $n$ из распределения $\mathcal{N}(a,\sigma^2)$ для трех различных случаев
# - $\theta = (a, \sigma^2)$;
# - $\theta = \sigma^2$, причем $a$ известно;
# - $\theta = a$, причем $\sigma^2$ известно.
#
# Для последнего случая посчитайте асимптотическую дисперсию оценки по теореме из лекции.
#
# **2.** Найдите оценку параметра $\theta$ методом максимального правдоподобия по выборке размера $n$ из распределения $\mathrm{Pois}(\theta)$. Посчитайте асимптотическую дисперсию по теореме из лекции, если оценка является асимптотически нормальной.

# %% [markdown]
# ---
# ### Задача 2.
# Пусть $X_1,...,X_n$ &mdash;  выборка из категориального распределения, то есть $\mathsf{P}_\theta(X_1 = j) = \theta_j$ для $j \in \{1, ..., k\}$, причем $\theta = (\theta_1, ..., \theta_k), \theta_j \geqslant 0$ и $\theta_1 + ... + \theta_k = 1$. Найдите оценку максимального правдоподобия параметра $\theta$ и проверьте ее на состоятельность.

# %% [markdown]
# ---
# ### Задача 3.

# %% [markdown]
# **Профиль Физика**
#
# Скачайте <a target="_blank" href="https://www.kaggle.com/datasets/fedesoriano/cern-electron-collision-data">данные</a> столкновениях частиц и оставьте следующие признаки:
# * `E1`, `E2` &mdash; полная энергия электронов (ГэВ);
# * `M` &mdash; инвариантная масса двух электронов (ГэВ).
#
# **Профиль Биология**
#
# Скачайте <a target="_blank" href="https://www.kaggle.com/datasets/ruslankl/mice-protein-expression">данные</a> экспрессии белков у белых мышей и оставьте следующие белки для анализа:
# * `ITSN1_N`
# * `DYRK1A_N`
# * `ELK_N`
#
# **Профиль Химия**
#
# Выберите любой вариант выше.
#
# ---
#
#
# **1.** Постройте для каждого из признаков гистограммы. Что можно сказать о характере распределения?

# %%
targetColumns = ['E1', 'E2', 'M']
data = pd.read_csv(r"dielectron.csv")[targetColumns]
data.describe().round(2)
# Out:
#               E1         E2         M
# count  100000.00  100000.00  99915.00
# mean       36.44      44.00     30.02
# std        41.22      46.75     25.26
# min         0.38       0.47      2.00
# 25%         8.46      11.06     12.45
# 50%        21.72      25.26     21.28
# 75%        50.00      66.93     39.03
# max       850.60     948.38    110.00

# %%
intervals = {'E1': (0, 200),
             'E2': (0, 200),
             'M': (0, 100)}

fig, ax = plt.subplots(2, 3, figsize = (21, 9), dpi = 150)

for ind, key in enumerate(targetColumns):
    ax[0, ind].hist(data[key],
                 bins = 70)
    ax[0, ind].set_title(key)
    ax[1, ind].hist(data[key],
                    bins = 100)
    ax[1, ind].set_xlim(intervals[key])
    
ax[0, 0].set_ylabel("Исходные распределения")
ax[1, 0].set_ylabel("Ограничение для устранения выбросов")
fig.suptitle("Гистограммы для различных признаков");

# %% [markdown]
# **Ответ:**
#
# Думаю что распределения параметров $E_{1}$ и $E_{2}$ - экспоненциальное. По крайней мере во втором дз удавалось приблизить распределение $E_{1}$ плотностью экспоненциального.
#
# Распределение $M$ похоже на гамма распределение. Но это не точно. Видно, что распределение неровное, присутствуют <<шумы>>.

# %% [markdown]
# **2.** Пусть есть выборка $X_1, ..., X_n$. Опишите процедуру бутстрепа построения доверительного интервала для величины $\theta = \mathsf{E} X_1$. Рассмотрите три типа  бутстрепных доверительных интервалов, выпишите формулу для каждого из них.

# %% [markdown]
# **Описание:**

# %% [markdown]
# **Нормальный интервал**
#
# Как мы знаем, $\overline{X}$ является ассимптотически нормальной оценкой математического ожидания с ассимтпотической дисперсией $\operatorname{D} X_{1}$.
#
# К, сожалению, дисперсия распределения исходной выборки нам не известна. Поэтому будем использовать бутстрепную оценку дисперсии $\hat{v}_{boot}$.
#
# Алгоритм нахождения $\hat{v}_{boot}$:
# - генерируем $B$ выборок на основе исходной. Просто заполняем матрицу размера $B \times n$ произвольно выбранными элементами исходной выборки
# - По каждой сгенерированной выборке считаем $\overline{X}$. Получаем столбец вида $(\overline{X}_{1}^{*}, \overline{X}_{2}^{*} \dots \overline{X}_{B}^{*})^{T}$
# - Теперь можем посчитать бутстрепную оценку дисперсии для рассматриваемого парметра: $\hat{v} = <\overline{X}^{2}> - (<\overline{X}>)^{2}$
# > тут $<X^{2}>$ обозначает среднее квадратов бутстрепных оценок
#
# Формула для доверительного интервала:
# $$
# \left(\hat{\theta} - z_{(1 + \alpha) / 2} \sqrt{\hat{v}_{boot}} , \hat{\theta} + z_{(1 + \alpha) / 2} \sqrt{\hat{v}_{boot}} \right)
# $$

# %% [markdown]
# **Центральный интервал**
#
# Создадим бутстрепную выборку, как описано ранее.  В результате получим распределение интересующей нас оценки. Посчитаем $(1 + \alpha) / 2$ и $(1 - \alpha) / 2 $ квантили данного распределения и в результате построим доверительный интервал:
#
# $$
# \left( 2\hat{\theta} - \theta^{*}_{(1+\alpha) / 2}, 2\hat{\theta} - \theta^{*}_{(1 - \alpha) / 2} \right)
# $$

# %% [markdown]
# **Квантильный интервал**
#
# Аналогично предыдущему, нужно просто посчитать квантили:
#
# $$
# \left( \theta^{*}_{(1-\alpha) / 2}, \theta^{*}_{(1+\alpha) / 2} \right)
# $$

# %% [markdown]
# **3.** Реализуйте функцию вычисления выборки оценок $\theta^*_1, \ldots \theta^*_B$ для оценки $\widehat \theta$ методом бутстрепа. Функция должна принимать на вход выборку и количество бутстрепных выборок $B$.

# %%
def estimator(sample):
    '''
    Делает необходимые преобразования с выборкой (выполняет подсчет статистики).
    Используется в функции bootstrap для вычисления оценок.
    
    :param sample: массив с числами
    :return: оценка, посчитанная по выборке
    '''
    
    return np.nanmean(sample, axis = 1)


def bootstrap(sample: np.ndarray, 
              B: int = 100_000)->np.ndarray:
    '''
    Реализует процедуру бутстрепа.
    
    :param sample: исходная выборка, по которой будут вычисляться бутстрепные оценки
    :param B: число бутстрепных оценок
    :return: возвращает массив длины B c бутстрепными оценками
    '''

    n = len(sample)  # длина выборки
    step = 100
    estimations = [estimator(np.random.choice(sample, size = (step, n))) for _ in np.arange(0, B, step)]
    return np.concatenate(estimations)

# %% [markdown]
# **4.** Реализуйте три типа бутстрепных доверительных интервалы в виде функций, принимающих на вход выборку оценок, полученных с помощью бутстрепа. Реализовывать вычисление бутстрепных интервалов для подвыборок размера от 1 до n не нужно, только для всей выборки.

# %%
def boostrap_normal_confidence_interval(bootstrap_estimations: np.ndarray,
                                        sample: np.ndarray,
                                        estimator_function: tp.Callable = np.mean,
                                        alpha: float = 0.95):
    estimation_value = estimator_function(sample)
    bootstrap_variance = np.mean(np.power(bootstrap_estimations, 2)) - np.power(np.mean(bootstrap_estimations), 2)
    z = sps.norm.ppf((1 - alpha) / 2)          
    return estimation_value - z * np.sqrt(bootstrap_variance), estimation_value + z * np.sqrt(bootstrap_variance)
    

    
def boostrap_central_confidence_interval(bootstrap_estimations: np.ndarray,
                                         sample: np.ndarray,
                                         estimator_function: tp.Callable = np.mean, 
                                         alpha: float = 0.95) -> tuple:
    doubled_estimation = 2 * estimator_function(sample)
    qLeft = np.quantile(bootstrap_estimations, q = (1 + alpha) / 2)
    qRight = np.quantile(bootstrap_estimations, q = (1 - alpha) / 2)
    return doubled_estimation - qLeft, doubled_estimation - qRight
    
def boostrap_quantile_confidence_interval(bootstrap_estimations, alpha=0.95):
    qLeft = np.quantile(bootstrap_estimations, q = (1 + alpha) / 2)
    qRight = np.quantile(bootstrap_estimations, q = (1 - alpha) / 2)
    return (qLeft, qRight)

# %% [markdown]
# **5.** Для каждого признака постройте бутстрепные доверительные интервалы для $\theta = \mathsf{E} X_1$ и сравните их.

# %% [markdown]
# Генерация бутстрепных оценок

# %%
bootstrap_estimations = {key: bootstrap(data[key]) for key in targetColumns}

# %% [markdown]
# Различные доверительные интервалы

# %%
quantConfInterval = {key: boostrap_quantile_confidence_interval(bootstrap_estimations[key]) for key in targetColumns}
centralConfInterval = {key: boostrap_central_confidence_interval(bootstrap_estimations[key], data[key]) for key in targetColumns}
normalConfInterval = {key: boostrap_normal_confidence_interval(bootstrap_estimations[key], data[key]) for key in targetColumns}

intervals = {'label': ['Нормальный доверительный интервал', 'Квантильный доверительный интервал', 'Центральный доверительный интервал'],
             'color': ['pink', 'darkcyan', 'orange'],
             'data': [normalConfInterval, quantConfInterval, centralConfInterval],
             'pos': 0.1 + np.arange(3) / 3}

# %%
for key in targetColumns:
    print(key)
    for j in range(3):
        width = np.abs(intervals['data'][j][key][0] - intervals['data'][j][key][1])
        print(intervals['label'][j] + ":  " + str([intervals['data'][j][key][i].round(3) for i in [0,1]]))
        print(f"Ширина интервала {round(width, 3)}")
# Out:
# E1
# Нормальный доверительный интервал:  [36.693, 36.18]
# Ширина интервала 0.512
# Квантильный доверительный интервал:  [36.694, 36.182]
# Ширина интервала 0.512
# Центральный доверительный интервал:  [36.179, 36.691]
# Ширина интервала 0.512
# E2
# Нормальный доверительный интервал:  [44.292, 43.714]
# Ширина интервала 0.578
# Квантильный доверительный интервал:  [44.293, 43.715]
# Ширина интервала 0.577
# Центральный доверительный интервал:  [43.713, 44.291]
# Ширина интервала 0.577
# M
# Нормальный доверительный интервал:  [30.176, 29.863]
# Ширина интервала 0.313
# Квантильный доверительный интервал:  [30.177, 29.863]
# Ширина интервала 0.315
# Центральный доверительный интервал:  [29.862, 30.176]
# Ширина интервала 0.315

# %%
fig, ax = plt.subplots(1, 3, figsize = (21, 6), dpi = 200)

for ind, key in enumerate(targetColumns):
    ax[ind].set_title(key)
    for j in range(3):
        key_interval = intervals['data'][j][key]
        yAx = np.linspace(0, 1, 100)
        if key_interval is not None:
            ax[ind].hlines(xmin = key_interval[0],
                           xmax = key_interval[1],
                           y = intervals['pos'][j],
                           color = intervals['color'][j],
                           label = intervals['label'][j])
            ax[ind].fill_betweenx(y = yAx, 
                                  x1 = key_interval[0], 
                                  x2 = key_interval[1],
                                  alpha = 0.05,
                                  color = intervals['color'][j])            
    ax[ind].axvline(x = data[key].mean(), 
                    linestyle = '--', 
                    color = 'red', 
                    alpha = 0.6,
                    label = 'Среднее значение выборки')
    ax[ind].set_ylim(0, 1)        
    ax[ind].legend()

fig.suptitle("Сравнение доверительных интервалов");

# %% [markdown]
# **Вывод:**
#
# Все рассматриваемые интервалы закрыли одинакувую область. Ширина интервалов практически одинаковая для каждой из выборок.
#
# По результатам эксперимента нельзя выделить лучший способ построения интервалов

# %% [markdown]
# ---
#
# ### Задача 4.
# В данной задаче нужно исследовать бутстрепные доверительные интервалы на примере гамма-распределения $\Gamma(\alpha, \beta)$ для величины $\mathsf{E}_{\theta} X_1 = \frac{\beta}{\alpha}$.

# %% [markdown]
# **1.** Сгенерируйте реализации выборки из $\Gamma(3, 2)$ размеров 5 и 100 и выведите реализации вышеупомянутых доверительных интервалов для этих двух реализаций. Сделайте **выводы**.
#
# *Замечания.*
#
# 1. Исходная выборка, по которой затем будут считаться бутстрепные оценки, генерируется один раз.
# 2. Процедуру бутстрепа для подсчета бутстрепных доверительных интервалов нужно выполнять один раз.

# %% [markdown]
# **Осторожно, далее ужасный код! Времени мало, никак не подправить**

# %%
smallSample = sps.gamma(loc = 0, a = 3, scale = 1 / 2).rvs(size = 5)
bigSample = sps.gamma(loc = 0, a = 3, scale = 1 / 2).rvs(size = 5)

bootstrap_small_sample = bootstrap(smallSample)
bootstrap_big_sample = bootstrap(bigSample)

quantConfInterval_bigSample = boostrap_quantile_confidence_interval(bootstrap_big_sample) 
centralConfInterval_bigSample = boostrap_central_confidence_interval(bootstrap_big_sample, bigSample)
normalConfInterval_bigSample = boostrap_normal_confidence_interval(bootstrap_big_sample, bigSample)

quantConfInterval_smallSample = boostrap_quantile_confidence_interval(bootstrap_small_sample) 
centralConfInterval_smallSample = boostrap_central_confidence_interval(bootstrap_small_sample, smallSample)
normalConfInterval_smallSample = boostrap_normal_confidence_interval(bootstrap_small_sample, smallSample)

intervalsBig = {'label': ['Нормальный доверительный интервал', 'Квантильный доверительный интервал', 'Центральный доверительный интервал'],
             'color': ['pink', 'darkcyan', 'orange'],
             'data': [normalConfInterval_bigSample, quantConfInterval_bigSample, centralConfInterval_bigSample],
             'pos': 0.1 + np.arange(3) / 3}
intervalsSmall = {'label': ['Нормальный доверительный интервал', 'Квантильный доверительный интервал', 'Центральный доверительный интервал'],
             'color': ['pink', 'darkcyan', 'orange'],
             'data': [normalConfInterval_smallSample, quantConfInterval_smallSample, centralConfInterval_smallSample],
             'pos': 0.1 + np.arange(3) / 3}

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4), dpi = 150)

ax[0].set_title("Большая выборка $n = 100$")
ax[1].set_title("Маленькая выборка $n = 5$")
for j in range(3):
    for intervals, axes in zip([intervalsBig, intervalsSmall], ax):
        key_interval = intervals['data'][j]
        width = np.abs(key_interval[0] - key_interval[1])
        print(intervals['label'][j] + f': ширина = {width:3f}')
        yAx = np.linspace(0, 1, 100)
        axes.hlines(xmin = key_interval[0],
                     xmax = key_interval[1],
                     y = intervals['pos'][j],
                     color = intervals['color'][j],
                     label = intervals['label'][j])
        axes.fill_betweenx(y = yAx, 
                           x1 = key_interval[0], 
                           x2 = key_interval[1],
                           alpha = 0.2,
                            color = intervals['color'][j])  
        axes.axvline(x = sps.gamma(loc = 0, a = 3, scale = 1 / 2).moment(1), 
                     color = 'red',
                     linestyle = '--')
        axes.legend()
        axes.set_ylim(0, 1.2)

fig.suptitle("Бутстрепные доверительные интервалы при различных размерах выборки");
# Out:
# Нормальный доверительный интервал: ширина = 1.059359
# Нормальный доверительный интервал: ширина = 0.609691
# Квантильный доверительный интервал: ширина = 1.092595
# Квантильный доверительный интервал: ширина = 0.620178
# Центральный доверительный интервал: ширина = 1.092595
# Центральный доверительный интервал: ширина = 0.620178

# %% [markdown]
# **Вывод**
#
# Как видим, при маленьком размере выборки бутстрепные доверительные интервалы не несут полезной информации. При $n = 5$ ни один из доверительных интервалов не <<закрыл>> реального параметра.
#
# Эксперимент позволяет сравнить различные типы доверительных интервалов. На выборке с $n = 100$ наилучшим образом сработали нормальный и квантильный доверительные интервалы.
#
# Нормальный интервал - самый узкий, соответственно, он даёт наилучшее представление о положении оцениваемого параметра.

# %% [markdown]
# **2.** Сравним все три типа интервалов. Во-первых, мы хотим, чтобы реальный уровень доверия этих доверительных интервалов был бы не менее 0.95. Это необходимое условие, при котором доверительный интервал корректно рассматривать. Во-вторых, мы хотим получить доверительный интервал как можно меньшей длины.
#
# Сгенерируйте $10^4$ выборок размера 5 из распределения $\Gamma(3, 2)$.

# %% [markdown]
# Генерация выборки размером $10^{4} \times 5$

# %%
sample = sps.gamma(loc = 0, a = 3, scale = 1 / 2).rvs(size = (int(1e5), 5))

# %% [markdown]
# По каждой выборке посчитайте выборку оценок методом бутстрепа с $B = 10^5$.
#
# *Предупреждение*: код может работать долго, особенно при неоптимальной реализации.

# %%
botstrap_estimaitons = [bootstrap(sample[ind], B = int(1e5)) for ind in range(sample.shape[0])]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 botstrap_estimaitons = [bootstrap(sample[ind], B = int(1e5)) for ind in range(sample.shape[0])]
#
# Cell In[66], line 1, in <listcomp>(.0)
# ----> 1 botstrap_estimaitons = [bootstrap(sample[ind], B = int(1e5)) for ind in range(sample.shape[0])]
#
# Cell In[13], line 25, in bootstrap(sample, B)
#      23 n = len(sample)  # длина выборки
#      24 step = 100
# ---> 25 estimations = [estimator(np.random.choice(sample, size = (step, n))) for _ in np.arange(0, B, step)]
#      26 return np.concatenate(estimations)
#
# Cell In[13], line 25, in <listcomp>(.0)
#      23 n = len(sample)  # длина выборки
#      24 step = 100
# ---> 25 estimations = [estimator(np.random.choice(sample, size = (step, n))) for _ in np.arange(0, B, step)]
#      26 return np.concatenate(estimations)
#
# KeyboardInterrupt:

# %% [markdown]
# Посчитайте реализации всех доверительных интервалов.

# %% [markdown]
# По полученным реализациям посчитайте
# * оценку реального уровня доверия &mdash; долю реализаций исходных выборок, для которых истинное значение оцениваемого параметра попадает в реализацию доверительного интервала;
# * среднюю длину реализаций доверительных интервалов.

# %% [markdown]
# **3.** Повторите эксперимент для выборок размера 100.

# %% [markdown]
# Сделайте общие **выводы** по задаче.

# %% [markdown]
# **Вывод:**

# %% [markdown]
# ---
# ### <b><i><font color="orange">Сложная часть</font></i></b>
#
# ### Задача 5.
# На высоте 1 метр от точки $\theta$ находится источник $\gamma$-излучения, который излучает безмассовых $\gamma$-котиков, причем направления траекторий $\gamma$-котиков случайны, т.е. равномерно распределены по полуокружности. Регистрируются координаты $X_i, i=1,...,n$ точек пересечения $\gamma$-котиков с поверхностью детекторной плоскости.
# - Найдите оценку максимального правдоподобия параметра $\theta$ для $n=1$ и $n=2$.
# - Найдите асимптотическую дисперсию, которую может обещать теорема о свойствах ОМП. Что мешает применить эту теорему? Сравните с оценкой с помощью выборочной медианы.

# %% [markdown]
# ### Задача 6.
#
#
# Сгенерируйте выборку $X = \left(X_1, \dots, X_{1000} \right)$ из стандартного распределения Коши. Для всех $n \leqslant 1000$ по первым $n$ элементам выборки $X_1, \dots, X_n$ вычислите значения следующих оценок:
# - $\overline{X}$  —  выборочное среднее;
# - $\overline{X}_{\alpha}$ —  усеченное среднее, где $\alpha$ &mdash; значение, на котором достигается минимум $\sigma^2_{\alpha}$;
# - $\widehat{\mu}$ —  выборочная медиана;
#
# а также, по каждой из этих оценок, одношаговую оценку.
#
# *Напоминание:* если $\widehat{\theta}_0$ — асимптотически нормальная оценка, то одношаговая оценка $\widehat{\theta}_1$ вычисляется как $\widehat{\theta}_1 = \widehat{\theta}_0 - \left(\ell''_X(\widehat{\theta}_0) \right)^{-1} \ell'_X(\widehat{\theta}_0)$, где $\ell_X(\theta)$ — логарифмическая функция правдоподобия. Заметим, что обычное выборочное среднее не является асимптотически нормальной оценкой, и оценка, вычисленная по формуле выше, формально не является одношаговой, однако ее все равно требуется посчитать.
#
# На одном графике изобразите зависимость значений этих оценок от $n$. Для каждой оценки $\widehat{\theta}_0$ соответствующая оценка $\widehat{\theta}_1$ должна быть изображена на графике пунктиром тем же цветом, что и $\widehat{\theta}_0$.
#
# Сравните асимптотические дисперсии оценок.
#
# *Замечание:* если некоторые оценки имеют большой разброс, и разница между графиками зависимостей оценок с малыми значениями недостаточно заметна, стоит сделать два графика, на одном из которых будут изображены все оценки, а на втором &mdash; только достаточно хорошие.

# %% [markdown]
# **Вывод:**
